# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd
df = pd.read_csv('/content/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ## Plot PDFs of Features

# %%
import matplotlib.pyplot as plt
import seaborn as sns

features_to_plot = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']

for feature in features_to_plot:
    plt.figure(figsize=(8, 6))
    sns.histplot(data=df, x=feature, kde=True, stat='density', color='skyblue')
    plt.title(f'PDF of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Density')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.show()

# %% [markdown]
# ## Bar Plot of Outcome

# %%
plt.figure(figsize=(7, 5))
sns.countplot(x='Outcome', data=df, hue='Outcome', palette='viridis', legend=False)
plt.title('Distribution of Diabetes Outcome')
plt.xlabel('Outcome (0: Non-Diabetic, 1: Diabetic)')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['Non-Diabetic', 'Diabetic'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## Glucose Distribution by Outcome

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df, x='Glucose', hue='Outcome', fill=True, common_norm=False, palette='coolwarm')
plt.title('Glucose Distribution by Diabetes Outcome')
plt.xlabel('Glucose Level')
plt.ylabel('Density')
plt.legend(title='Outcome', labels=['Non-Diabetic', 'Diabetic'])
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ## Calculate and Visualize Correlations

# %%
correlations = df.corr()['Outcome'].drop('Outcome')

plt.figure(figsize=(10, 7))
sns.barplot(x=correlations.index, y=correlations.values, hue=correlations.index, palette='RdBu_r', legend=False)
plt.title('Correlation of Features with Diabetes Outcome')
plt.xlabel('Features')
plt.ylabel('Correlation with Outcome')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
